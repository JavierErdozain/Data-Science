# %% [markdown]
# # 03 - ACB - Analizando datos
# <hr>

# %%
# Librerías generales.
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# Cargamos los datos y echamos un vistazo a su tamaño, a sus campos y tipos de datos.
filepath="csv/infoEstadisticasACB_2000.csv"
dt_datos=pd.read_csv(filepath, delimiter=",", encoding = "ISO-8859-1")

# %%
dt_datos.head()
# Out:
#    Temporada  Jornada Equipo LoV Minutos  Puntos     T1  %T1     T2  %T2  \
# 0       2000        1    GCA   L  100:00      81  14/19  74%  29/48  60%
# 1       2000        1    CSF   V  100:00      76  10/17  59%  18/37  49%
# 2       2000        1    BRE   L  100:00      84  19/26  73%  25/48  52%
# 3       2000        1    OUR   V  100:00      85  29/35  83%  19/34  56%
# 4       2000        1    ALI   L  100:00      59  11/16  69%  15/29  52%
#
#       T3  %T3   T  Valoración  Puntos_1C  Puntos_2C  Puntos_2C.1  Puntos_3C  \
# 0   3/12  25%  39          86        NaN        NaN          NaN        NaN
# 1  10/20  50%  21          85        NaN        NaN          NaN        NaN
# 2   5/13  38%  25          79        NaN        NaN          NaN        NaN
# 3   6/14  43%  28          88        NaN        NaN          NaN        NaN
# 4   6/22  27%  24          56        NaN        NaN          NaN        NaN
#
#   Puntos_PR
# 0
# 1
# 2
# 3
# 4

# %%
dt_datos.describe()
# Out:
#        Temporada     Jornada      Puntos           T  Valoración  Puntos_1C  \
# count      660.0  660.000000  660.000000  660.000000  660.000000        0.0
# mean      2000.0   19.051515   80.104545   34.140909   83.293939        NaN
# std          0.0   10.997603   11.116693    5.821823   20.956599        NaN
# min       2000.0    1.000000   52.000000   16.000000   33.000000        NaN
# 25%       2000.0   10.000000   72.000000   30.000000   68.000000        NaN
# 50%       2000.0   19.000000   79.000000   34.000000   82.000000        NaN
# 75%       2000.0   28.000000   87.000000   38.000000   98.000000        NaN
# max       2000.0   46.000000  117.000000   50.000000  155.000000        NaN
#
#        Puntos_2C  Puntos_2C.1  Puntos_3C
# count        0.0          0.0        0.0
# mean         NaN          NaN        NaN
# std          NaN          NaN        NaN
# min          NaN          NaN        NaN
# 25%          NaN          NaN        NaN
# ...

# %% [markdown]
# Analizaremos algunos datos del equipo "TAU".
#
# ¿Mejoran los porcentajes de tiro con forme avanza la temporada?

# %%
dt_fitro_porcentajes = dt_datos.loc[((dt_datos['Temporada'] == 2000) & 
                                 (dt_datos['Equipo']=='RMB')), 
                                ['Temporada','Jornada', 'Equipo',
                                 '%T1', '%T2', '%T3']]

# %%
a = dt_fitro_porcentajes['%T1'].str[0:-1].astype(int)

# %%
plt.plot(np.array(dt_fitro_porcentajes['Jornada']),
         np.array(dt_fitro_porcentajes['%T1'].str[0:-1].astype(int)))
#plt.plot(np.array(dt_fitro_porcentajes['%T2']))
#plt.plot(np.array(dt_fitro_porcentajes['%T3']))
plt.show()
